# %%
# !pip3 install natsort
# Out:
# /home/shazil/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: 0.1.36ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/shazil/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: 0.23ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# ...

# %%
# importing the modules
import os
import shutil
import natsort

# %%
# Providing the folder path

target = 'red card data'
origin = []

for count,filename in enumerate(os.listdir(target)):

    origin.append(filename)
    
origin
# Out:
# ['49.jpg',
#  '50.jpg',
#  '51.jpg',
#  '52.jpg',
#  '53.jpg',
#  '54.jpg',
#  '55.jpg',
#  '56.jpg',
#  '57.jpg',
#  '58.jpg',
#  '59.jpg',
#  '60.jpg',
#  '61.jpg',
#  '62.jpg',
#  '63.jpg',
#  '64.jpg',
#  '65.jpg',
#  '67.jpg',
#  '68.jpg',
#  '69.jpg',
#  '120.jpg',
#  '121.jpg',
#  '122.jpg',
#  '123.jpg',
#  '124.jpg',
#  '125.jpg',
#  '126.jpg',
#  '127.jpg',
#  '128.jpg',
#  '129.jpg',
#  '130.jpg',
#  '131.jpg',
#  '132.jpg',
#  '133.jpg',
#  '134.jpg',
#  '135.jpg',
#  '136.jpg',
#  '182.jpg',
#  '198.jpg',
#  '211.jpg',
#  '230.jpg',
#  '48.jpg',
#  '66.jpg',
#  '137.jpg',
#  '138.jpg',
#  '139.jpg',
#  '140.jpg',
#  '141.jpg',
#  '142.jpg',
#  '143.jpg',
#  '183.jpg',
#  '184.jpg',
#  '185.jpg',
#  '186.jpg',
#  '187.jpg',
#  '188.jpg',
#  '189.jpg',
#  '190.jpg',
#  '191.jpg',
#  '192.jpg',
#  '199.jpg',
#  '200.jpg',
#  '201.jpg',
#  '202.jpg',
#  '203.jpg',
#  '204.jpg',
#  '205.jpg',
#  '206.jpg',
#  '207.jpg',
#  '208.jpg',
#  '209.jpg',
#  '210.jpg',
#  '212.jpg',
# ...

# %%
# fetching last filename of main folder (folder '1')
# lastFileName = int((natsort.natsorted(os.listdir(target))[-1])[:-4])
# lastFileName

# renaming all files in origin folder and moving to main folder (folder '1')
name = 1

# for folder in origin:
for count,filename in enumerate(os.listdir(target)):
    os.rename(target+'/'+str(filename), target+'/'+f"{str(name)}.jpg")
    name+=1
        
# removing empty folders     
#     os.rmdir(folder)
